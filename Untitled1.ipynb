# %%
def Maximum_Opening():
    Kongzui_data = {
        '定位': '在前臂掌面橈側，當尺澤與太淵連線上，腕橫紋上 7寸處。',
        '解剖': '有肱橈肌，在旋前圓肌上端之外緣，橈側腕長、短伸肌的內緣；有頭靜脈、橈動、靜脈；布有前臂外側皮神經，橈神經淺支。',
        '主治': '咳嗽，氣喘，咳血，咽喉腫痛，肘臂攣病，痔疾。',
        '配伍': '配肺俞尺澤治咳嗽，氣喘；配魚際治咳血。',
        '刺灸法': '直刺0.5～1寸。'
    }
    return Kongzui_data



def  Broken_Sequence():
    Lieque_data = {
        '定位': '在前臂橈側緣，橈骨莖突上方，腕橫紋上1.5寸，當肱橈肌與拇長展肌腱之間。',
        '解剖': '在肱橈肌腱與拇長展肌腱之間，橈側腕長伸肌腱內側；有頭靜脈，橈動、靜脈分支；布有前臂外側皮神經和橈神經淺支的混合支。',
        '主治': '傷風，頭痛，項強，咳嗽，氣喘，咽喉腫痛，口眼歪斜，齒痛。',
        '配伍': '配合谷治傷風頭痛項強; 配肺俞治咳嗽氣喘。',
        '刺灸法': '向上斜刺0.3～0.5寸。'
    }
    return Lieque_data


def  Channel_Gutter():
    Jingqu_data = {
        '定位': '在前臂掌面橈側，橈骨莖突與橈動脈之間凹陷處，腕橫紋上1寸。',
        '解剖': '橈側腕屈肌腱的外側，有旋前方肌當橈動、靜脈外側處；布有前臂外側皮神經和橈神經淺支混合支。',
        '主治': '咳嗽，氣喘，胸痛，咽喉腫痛，手腕痛。',
        '配伍': '配肺俞，尺澤治咳嗽。',
        '刺灸法': '避開橈動脈，直刺0.3～0.5寸。'
    }
    return Jingqu_data

def  Suprem_Abyss():
    Taiyuan_data = {
        '定位': ' 在腕掌側橫紋橈側，橈動脈搏動處。',
        '解剖': ' 橈側腕屈肌腱的外側，拇展長肌腱內測；有橈動、靜脈；布有前臂外側皮神經和橈神經淺支混合支。',
        '主治': ' 咳嗽 ，氣喘 ，咳血 ，胸痛 ，咽喉腫痛，腕臂痛，無脈症。',
        '配伍': '配尺澤，魚際，肺俞治咳嗽，咳血，胸痛；配人迎治無脈症。',
        '刺灸法': '避開橈動脈，直刺0.3～0.5寸。'
    }
    return Taiyuan_data

def  Fish_Border():
    Yuji_data = {
        '定位': '位於手拇指本節（第一掌指並節）後，約第一掌骨中點，赤白肉際處',
        '解剖': '有拇短展肌和拇指對掌肌；血管當拇指靜脈迴流支；布有前臂外側皮神經和橈神經淺支混合支。',
        '主治': ' 咳嗽，咳血，咽喉腫痛 ，失音，發熱',
        '配伍': ' 配孔最,尺澤治咳嗽,咳血;配少商治咽喉腫痛。',
        '刺灸法': '直刺0.5～0.8寸。'
    }
    return Yuji_data

def Lung_Meridian_of_Hand_Taiyin():
    acupoints_info = {
        '孔最穴': Maximum_Opening(),
        '列缺穴': Broken_Sequence(),
        '經渠穴': Channel_Gutter(),
        '太淵穴': Suprem_Abyss(),
        '魚際穴': Fish_Border()
        # ... 其他穴位
    }
    return acupoints_info

def get_acupoint_info(acupoint_name, info_category=None):
    acupoints_info = Lung_Meridian_of_Hand_Taiyin()

    acupoint_data = acupoints_info.get(acupoint_name, None)
    if acupoint_data is None:
        return "未找到指定的穴位信息。"

    if info_category:
        return acupoint_data.get(info_category, "未找到指定類別的信息。")

    return acupoint_data

def query_acupoint():
    while True:
        print("\n--- 查詢系統 ---")
        acupoint_name = input("請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:\n(孔最穴、列缺穴、經渠穴、太淵穴、魚際穴選擇其一owo):")
        if acupoint_name == "退出":
            print("\n--- 已退出查詢 ---")
            print("感謝使用本系統，祝你好運owo")
            break

        acupoint_info = get_acupoint_info(acupoint_name)
        if "未找到" in acupoint_info:
            print(f"\n{acupoint_info}\n")
            continue

        while True:
            print(f"\n找到穴位：{acupoint_name}")
            print("可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法")
            info_category = input("請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:")

            if info_category == "返回":
                print("\n返回上一層...\n")
                break
            elif info_category == "全部":
                print(f"\n{acupoint_name} - 全部信息:")
                for category, detail in acupoint_info.items():
                    print(f"{category}: {detail}")
                print()  # 為了排版整潔owo
            elif info_category in ["定位", "解剖", "主治", "配伍", "刺灸法"]:
                category_info = get_acupoint_info(acupoint_name, info_category)
                print(f"\n{acupoint_name} - {info_category}:\n{category_info}\n")
            else:
                print("\n輸入的信息類別不正確，請重新輸入。\n")

            # 再次查詢或返回
            while True:
                next_action = input("輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：")
                if next_action in ["再查詢", "返回"]:
                    break
                else:
                    print("請輸入有效的指令（'再查詢' 或 '返回'）。")
            if next_action == "返回":
                print("\n返回穴位選擇...")
                break
# 啟動查詢
query_acupoint()
# Out:
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (孔最穴、列缺穴、經渠穴、太淵穴、魚際穴選擇其一owo):孔最穴
#
# 找到穴位：孔最穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:定位
#
# 孔最穴 - 定位:
# 在前臂掌面橈側，當尺澤與太淵連線上，腕橫紋上 7寸處。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：返回
#
# 返回穴位選擇...
#
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (孔最穴、列缺穴、經渠穴、太淵穴、魚際穴選擇其一owo):退出
#
# --- 已退出查詢 ---
# 感謝使用本系統，祝你好運owo
